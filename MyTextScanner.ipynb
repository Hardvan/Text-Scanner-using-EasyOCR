# %% [markdown]
# # Text Scanner using `EasyOCR`
# OCR: Optical Character Recognition

# %% [markdown]
# ## 1. Installing Dependencies

# %%
# !pip install torch torchvision torchaudio
# !pip install easyocr
# Out:
# Requirement already satisfied: torch in f:\textscanner\.venv\lib\site-packages (2.0.0)
# Requirement already satisfied: torchvision in f:\textscanner\.venv\lib\site-packages (0.15.1)
# Requirement already satisfied: torchaudio in f:\textscanner\.venv\lib\site-packages (2.0.1)
# Requirement already satisfied: typing-extensions in f:\textscanner\.venv\lib\site-packages (from torch) (4.5.0)
# Requirement already satisfied: networkx in f:\textscanner\.venv\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in f:\textscanner\.venv\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: filelock in f:\textscanner\.venv\lib\site-packages (from torch) (3.11.0)
# Requirement already satisfied: sympy in f:\textscanner\.venv\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: requests in f:\textscanner\.venv\lib\site-packages (from torchvision) (2.28.2)
# Requirement already satisfied: numpy in f:\textscanner\.venv\lib\site-packages (from torchvision) (1.24.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in f:\textscanner\.venv\lib\site-packages (from torchvision) (9.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\textscanner\.venv\lib\site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: mpmath>=0.19 in f:\textscanner\.venv\lib\site-packages (from sympy->torch) (1.3.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'F:\TextScanner\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: easyocr in f:\textscanner\.venv\lib\site-packages (1.6.2)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in f:\textscanner\.venv\lib\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: numpy in f:\textscanner\.venv\lib\site-packages (from easyocr) (1.24.2)
# Requirement already satisfied: Shapely in f:\textscanner\.venv\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: pyclipper in f:\textscanner\.venv\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: PyYAML in f:\textscanner\.venv\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: torch in f:\textscanner\.venv\lib\site-packages (from easyocr) (2.0.0)
# Requirement already satisfied: ninja in f:\textscanner\.venv\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: Pillow in f:\textscanner\.venv\lib\site-packages (from easyocr) (9.5.0)
# Requirement already satisfied: torchvision>=0.5 in f:\textscanner\.venv\lib\site-packages (from easyocr) (0.15.1)
# Requirement already satisfied: python-bidi in f:\textscanner\.venv\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: scipy in f:\textscanner\.venv\lib\site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: scikit-image in f:\textscanner\.venv\lib\site-packages (from easyocr) (0.20.0)
# Requirement already satisfied: requests in f:\textscanner\.venv\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.2)
# Requirement already satisfied: filelock in f:\textscanner\.venv\lib\site-packages (from torch->easyocr) (3.11.0)
# Requirement already satisfied: sympy in f:\textscanner\.venv\lib\site-packages (from torch->easyocr) (1.11.1)
# Requirement already satisfied: networkx in f:\textscanner\.venv\lib\site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in f:\textscanner\.venv\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: typing-extensions in f:\textscanner\.venv\lib\site-packages (from torch->easyocr) (4.5.0)
# Requirement already satisfied: six in f:\textscanner\.venv\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: lazy_loader>=0.1 in f:\textscanner\.venv\lib\site-packages (from scikit-image->easyocr) (0.2)
# Requirement already satisfied: imageio>=2.4.1 in f:\textscanner\.venv\lib\site-packages (from scikit-image->easyocr) (2.27.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in f:\textscanner\.venv\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: tifffile>=2019.7.26 in f:\textscanner\.venv\lib\site-packages (from scikit-image->easyocr) (2023.4.12)
# Requirement already satisfied: packaging>=20.0 in f:\textscanner\.venv\lib\site-packages (from scikit-image->easyocr) (23.1)
# Requirement already satisfied: MarkupSafe>=2.0 in f:\textscanner\.venv\lib\site-packages (from jinja2->torch->easyocr) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in f:\textscanner\.venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in f:\textscanner\.venv\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'F:\TextScanner\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# 2. Importing Libraries

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 3. Reading Text in Image

# %%
IMAGE_PATH = "./images/surf.jpg"

# %%
# Create a reader
reader = easyocr.Reader(['en'])

# Read the image
result = reader.readtext(IMAGE_PATH)

# Display the result
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[68, 62], [544, 62], [544, 260], [68, 260]], 'SUF', 0.7241527880145537)]

# %% [markdown]
# ## 4. Drawing Ressult

# %%
top_left = tuple(result[0][0][0])
bottom_right = tuple(result[0][0][2])
text = result[0][1]

# Read the image
img = cv2.imread(IMAGE_PATH)

# Draw the bounding box
img = cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 5)

# Put the text
img = cv2.putText(img, text, top_left, cv2.FONT_HERSHEY_SIMPLEX,
                  1, (255, 255, 255), 2, cv2.LINE_AA)

# Display the image
plt.imshow(img)
plt.show()

# %% [markdown]
# ### Trying for different image

# %%
IMAGE_PATH = "./images/out-of-service.jpg"

# %%
# Create a reader
reader = easyocr.Reader(['en'])

# Read the image
result = reader.readtext(IMAGE_PATH)

# Display the result
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[590, 1493], [1797, 1493], [1797, 1785], [590, 1785]],
#   'OUT OF',
#   0.8607063801603826),
#  ([[492, 1846], [1884, 1846], [1884, 2134], [492, 2134]],
#   'SERVICE',
#   0.9996598920221639),
#  ([[1520, 2231], [1909, 2231], [1909, 2251], [1520, 2251]],
#   'AUSTRALIAN SAFETY SIGNS by StikyStuf 1800 33 03 63',
#   0.6763146474588352),
#  ([[1604, 2249], [1825, 2249], [1825, 2267], [1604, 2267]],
#   'Www.australiansafetysigns.com',
#   0.5737382267340296)]

# %%
img = cv2.imread(IMAGE_PATH)
for detection in result:
    top_left = tuple([int(val) for val in detection[0][0]])
    bottom_right = tuple([int(val) for val in detection[0][2]])
    text = detection[1]

    img = cv2.rectangle(img, top_left, bottom_right, (0, 255, 0), 5)
    img = cv2.putText(img, text, top_left, cv2.FONT_HERSHEY_SIMPLEX,
                      2, (255, 255, 255), 2, cv2.LINE_AA)

plt.imshow(img)
plt.show()
